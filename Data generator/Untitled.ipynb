# %%
import random as rand
import numpy as np
import pandas as pd 
import csv
import pylab as pl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import svm, linear_model, cross_validation

# %%
np.random.seed(10)
num = 1000

# %%
def generateRace(races=4, probability=0.3, size=1):
    r = np.random.binomial(races, probability, size)
    return r

def generateScore(low, high, size=1):
#     y = np.absolute(np.sin(np.random.uniform(size=size, low=low, high=high)))
    y = np.random.normal(0.5, 0.1, size=1000)
    return y

def generateGender(number=1, probability=0.3, size=1):
    Gender = np.random.binomial(number, probability, size=size)
    return Gender

def generateTitle(size = 1):
    titles = []
    for i in range(0,size):   
        title = ["developer", "secertary", "doctor", "web designer"]
        x = rand.choice(title)
        titles.append(x)
    return titles

def generatehardSkills(size = 1):
    hardSkillsLast = []
    for i in range(0,size):   
        hardSkills = ["java", "office", "lighthand", "python"]
        x = rand.choice(hardSkills)
        hardSkillsLast.append(x)
    return hardSkillsLast

def generateSoftSkills(size = 1):
    softSkillsLast = []
    for i in range(0,size):   
        softSkills = ["languages", "communacative", "creative"]
        x = rand.choice(softSkills)
        softSkillsLast.append(x)
    return softSkillsLast

# %%
df = pd.DataFrame(columns=["Gender", "title", "hardSkills","softSkills", "Race"])
df["Gender"] = generateGender(size = num)
numFemale = len(df[df["Gender"] == 0])
df["Race"] = generateRace(size = num)
df["title"] = generateTitle(size = num)
df["hardSkills"] = generatehardSkills(size = num)
df["softSkills"] = generateSoftSkills(size = num)
df.to_csv("test.csv")
df
# Out:
#      Gender         title hardSkills     softSkills  Race
# 0         1     developer  lighthand      languages     0
# 1         0  web designer       java       creative     0
# 2         1     developer       java      languages     1
# 3         0        doctor       java  communacative     1
# 4         1     developer     python  communacative     0
# 5         0  web designer       java  communacative     1
# 6         0     developer     office       creative     1
# 7         1     developer     python  communacative     1
# 8         0     developer     python  communacative     1
# 9         0  web designer  lighthand  communacative     1
# 10        1     secertary     python       creative     0
# 11        0     secertary     python  communacative     2
# 12        0     developer  lighthand      languages     1
# 13        1        doctor     office      languages     3
# 14        0        doctor     office      languages     2
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Volumes/Data/M1D0Z82/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Score'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
case_list = {}
for i in df:
    case = {'Gender': df[i], 'Race': df[i], 'hard-skills':df[i] }
    case_list[i] = case

# %%
df.to_dict()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(df[df["Gender"]==0]["Score"],countScoreMale, label='Male', c='b')
ax1.scatter(df[df["Gender"]==1]["Score"],countScoreFemale, label='Female', c='r')
plt.show()

# %%
# split into train and test set
X_train, X_test, y_train, y_test = train_test_split(df, df['Gender'], test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# %%
pl.scatter(X_train[idx, 0], X_train[idx, 1], c=y_train[idx], marker='^', cmap=pl.cm.Blues, s=100)
pl.scatter(X_train[~idx, 0], X_train[~idx, 1], c=y_train[~idx],
    marker='o', cmap=pl.cm.Blues, s=100)
pl.arrow(0, 0, 8 * w[0], 8 * w[1], fc='gray', ec='gray',
    head_width=0.5, head_length=0.5)
pl.text(0, 1, '$w$', fontsize=20)
pl.arrow(-3, -8, 8 * w[0], 8 * w[1], fc='gray', ec='gray',
    head_width=0.5, head_length=0.5)
pl.text(-2.6, -7, '$w$', fontsize=20)
pl.axis('equal')
pl.show()

# %%
size = 100
titles = []
for i in range(0,size):   
    title = ["developer", "secertary", "doctor", "web designer"]
    x = rand.choice(title)
    titles.append(x)
print(titles)
